# %%
# Import section 
import scipy.stats as stats # It has all probablity distribution along with many statistical function
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings                             
warnings.filterwarnings('ignore') # To supress warnings
# sns.set(style="darkgrid") # set the background for the graphs
# from scipy.stats import skew

# %%
#Reading data from salary.csv
df = pd.read_csv('Salary Data.csv')
insured = df.copy()

# %%
insured.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
insured.tail(5)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
insured.info() #it give information about data type of column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
insured.describe()  # it describe mean ,max,min,std, Q1,Q2,Q3, count
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
insured.shape
print(insured.shape)
#get the size of the data frame  eg :- rows and column
print("--Indicate total number of rows and columns in a data set --")
print("Rows :",insured.shape[0])
print("Column :",insured.shape[1])
# Out:
# (375, 6)
# --Indicate total number of rows and columns in a data set --
# Rows : 375
# Column : 6

# %%
insured.isnull()  #Return True if null
# Out:
#        Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0    False   False            False      False                False   False
# 1    False   False            False      False                False   False
# 2    False   False            False      False                False   False
# 3    False   False            False      False                False   False
# 4    False   False            False      False                False   False
# ..     ...     ...              ...        ...                  ...     ...
# 370  False   False            False      False                False   False
# 371  False   False            False      False                False   False
# 372  False   False            False      False                False   False
# 373  False   False            False      False                False   False
# 374  False   False            False      False                False   False
#
# [375 rows x 6 columns]

# %%
insured.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
insured.isnull().sum().values.sum()
# Out:
# 12

# %%
print('\Values :\n',insured.values)
print('\nFeature :\n',insured.columns)
# Out:
# \Values :
#  [[32.0 'Male' "Bachelor's" 'Software Engineer' 5.0 90000.0]
#  [28.0 'Female' "Master's" 'Data Analyst' 3.0 65000.0]
#  [45.0 'Male' 'PhD' 'Senior Manager' 15.0 150000.0]
#  ...
#  [29.0 'Female' "Bachelor's" 'Junior Project Manager' 2.0 40000.0]
#  [34.0 'Male' "Bachelor's" 'Senior Operations Coordinator' 7.0 90000.0]
#  [44.0 'Female' 'PhD' 'Senior Business Analyst' 15.0 150000.0]]
#
# Feature :
#  Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
print('\nmissing values :\n',insured.isnull().sum().values.sum())
print('\nFeature list:\n',insured.columns.to_list())
print('\nUnique Values in data sets :- \n',insured.nunique())
# Out:
# missing values :
#  12
#
# Feature list:
#  ['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience', 'Salary']
#
# Unique Values in data sets :-
#  Age                     31
# Gender                   2
# Education Level          3
# Job Title              174
# Years of Experience     28
# Salary                  36
# dtype: int64

# %%
insured = insured.dropna()

# %%
insured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 373 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 20.4+ KB

# %%
insured.isnull().sum()
# after removing the null every data will be null
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
# changing the dtype to category to save memory 
insured['Gender'] = insured['Gender'].astype("category")
insured['Education Level'] = insured['Education Level'].astype("category")
insured['Job Title'] = insured['Job Title'].astype("category")

# %%
insured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 373 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    category
#  2   Education Level      373 non-null    category
#  3   Job Title            373 non-null    category
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: category(3), float64(3)
# memory usage: 18.8 KB

# %%
insured.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
#get count of unique observation for each category variable
list_cols = insured.select_dtypes(['category']).columns
list_cols
# Out:
# Index(['Gender', 'Education Level', 'Job Title'], dtype='object')

# %%
list_cols = insured[insured.select_dtypes(['category']).columns]
list_cols
# Out:
#      Gender Education Level                      Job Title
# 0      Male      Bachelor's              Software Engineer
# 1    Female        Master's                   Data Analyst
# 2      Male             PhD                 Senior Manager
# 3    Female      Bachelor's                Sales Associate
# 4      Male        Master's                       Director
# ..      ...             ...                            ...
# 370  Female      Bachelor's       Senior Marketing Analyst
# 371    Male        Master's         Director of Operations
# 372  Female      Bachelor's         Junior Project Manager
# 373    Male      Bachelor's  Senior Operations Coordinator
# 374  Female             PhD        Senior Business Analyst
#
# [373 rows x 3 columns]

# %%
# types of gender and their counts 
insured['Gender'].value_counts()
# Out:
# Gender
# Male      194
# Female    179
# Name: count, dtype: int64

# %%
insured['Education Level'].value_counts()
# Out:
# Education Level
# Bachelor's    224
# Master's       98
# PhD            51
# Name: count, dtype: int64

# %%
dict(insured['Education Level'].value_counts())
# Out:
# {"Bachelor's": 224, "Master's": 98, 'PhD': 51}

# %%
insured['Job Title'].value_counts()
# Out:
# Job Title
# Director of Marketing                 12
# Director of Operations                11
# Senior Business Analyst               10
# Senior Marketing Analyst               9
# Senior Marketing Manager               9
#                                       ..
# Junior Designer                        1
# Junior Data Scientist                  1
# Junior Data Analyst                    1
# Junior Customer Support Specialist     1
# Web Developer                          1
# Name: count, Length: 174, dtype: int64

# %%
list_cols = insured.select_dtypes(['category']).columns
print(list_cols)
# insured[list_cols[i]] is give category based data
for i in range (len(list_cols)):
    print (insured[list_cols[i]].value_counts())
# Out:
# Index(['Gender', 'Education Level', 'Job Title'], dtype='object')
# Gender
# Male      194
# Female    179
# Name: count, dtype: int64
# Education Level
# Bachelor's    224
# Master's       98
# PhD            51
# Name: count, dtype: int64
# Job Title
# Director of Marketing                 12
# Director of Operations                11
# Senior Business Analyst               10
# Senior Marketing Analyst               9
# Senior Marketing Manager               9
#                                       ..
# Junior Designer                        1
# Junior Data Scientist                  1
# Junior Data Analyst                    1
# Junior Customer Support Specialist     1
# Web Developer                          1
# Name: count, Length: 174, dtype: int64

# %%
# # Function to create barplots that indicate percentage for each category.
def bar_perc(plot, feature):
    total = len(feature) # length of the column
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot
        plot.annotate(percentage, (x, y), size = 12) # annotate the percentage

# %%
len(insured[insured['Gender']=='Female'])
# Out:
# 179

# %%
num_of_female = len(insured[insured['Gender']=='Female'])
num_of_male = len(insured[insured['Gender']=='Male'])
plt.bar(["Male","Female"],[num_of_male,num_of_female],color =['r','g'],label =['Male','Female'])
plt.legend()
plt.show()

# %%
# insured['Gender'] it only give gender column data 
plot_data = dict(insured['Gender'].value_counts()) #gives gender on basis of count
print(plot_data)
plt.bar(['Male','Female'],[plot_data['Male'],plot_data['Female']],color=['r','g'],label =['Male','Female'])
plt.legend()
plt.show()
# Out:
# {'Male': 194, 'Female': 179}

# %%
insured['Gender'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Gender'>

# %%
#Alternet
#for education level
no_of_bach = len(insured[insured['Education Level'] == "Bachelor's"])
no_of_mast = len(insured[insured['Education Level'] == "Master's"])
no_of_phd = len(insured[insured['Education Level'] == 'PhD'])

plt.bar(["Bachelor's","Master's","PhD"],[no_of_bach,no_of_mast,no_of_phd], color = ['r','g','b'], label=["Bachelor's","Master's","PhD"])
plt.title('No of people with Education level')
plt.legend()
plt.show()

# %%
plot_data.keys()
# Out:
# dict_keys(['Male', 'Female'])

# %%
plot_data.values()
# Out:
# dict_values([194, 179])

# %%
plot_data = dict(insured['Education Level'].value_counts())
print(plot_data)
plt.bar(plot_data.keys(),plot_data.values(),label =plot_data.keys(),color=['r','g'])
plt.legend()
plt.show()
# Out:
# {"Bachelor's": 224, "Master's": 98, 'PhD': 51}

# %%
labels = list(dict(insured['Education Level'].value_counts()).keys())
print(labels)
insured['Education Level'].value_counts().plot.bar(color =['r','b','g'])
plt.legend()
# Out:
# ["Bachelor's", "Master's", 'PhD']

# %%
labels = list(dict(insured['Education Level'].value_counts()).keys())
labels
insured['Education Level'].value_counts().plot.pie(labels = labels)
# insured['Education Level']
# Out:
# <Axes: ylabel='count'>

# %%
len(dict(insured['Job Title'].value_counts()).keys())
# Out:
# 174

# %%
insured['Job Title'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Job Title'>

# %%
# Import for exercise 
# {'Gender': [['Male', 'Female'], [194, 179]], 'Education Level': [["Bachelor's", "Master's", 'PhD']}
data = {}
list_cols = insured.select_dtypes(['category']).columns
print(list_cols) 
for i in range(len(list_cols)):
    values = list(insured[list_cols[i]].value_counts())
    keys = list(insured[list_cols[i]].value_counts().keys())
    # print(keys)
    # print(values)
    data[list_cols[i]] = [keys,values]
# data
print(data)
# Out:
# Index(['Gender', 'Education Level', 'Job Title'], dtype='object')
# ...

# %%
insured
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
# insured["Gender"] 
# corr means correlation 
corr_insured = insured[['Age','Years of Experience','Salary']]
corr_insured.corr()
# Out:
#                           Age  Years of Experience    Salary
# Age                  1.000000             0.979128  0.922335
# Years of Experience  0.979128             1.000000  0.930338
# Salary               0.922335             0.930338  1.000000

# %%
plt.figure(figsize = (15,5))
sns.heatmap(corr_insured.corr(),annot = True)
plt.show()

# %%
plt.figure(figsize=(9,9))
sns.pairplot(data = insured)
plt.show()

# %%
# Gender count plot 
plt.figure(figsize = (13,5))
ax = sns.countplot(x= 'Education Level',hue= 'Gender',data = insured)
plt.title("sex vs Education Level")
bar_perc(ax,insured['Education Level'])

# %%
# sex vs Eduaction level 
plt.figure(figsize = (13,5))
sns.countplot(x='Gender',hue="Education Level", data = insured)
plt.title("sex vs Education Level")
plt.show()

# %%
insured.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
# Group by Gender 
insured.groupby(insured['Gender']).Salary.mean()
# Out:
# Gender
# Female     97011.173184
# Male      103867.783505
# Name: Salary, dtype: float64

# %%
insured.groupby(insured['Gender']).Salary.mean().plot.bar()
# Out:
# <Axes: xlabel='Gender'>

# %%
insured.groupby(insured['Education Level']).Salary.mean()
# Out:
# Education Level
# Bachelor's     74756.026786
# Master's      129795.918367
# PhD           157843.137255
# Name: Salary, dtype: float64

# %%
insured.rename(columns ={'Years of Experience':'Years_of_Experience','Education Level':'Education_Level'},inplace = True)

# %%
insured
# Out:
#       Age  Gender Education_Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years_of_Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
insured.groupby(insured['Education_Level']).Years_of_Experience.mean() #Group by education level
# Out:
# Education_Level
# Bachelor's     6.966518
# Master's      13.397959
# PhD           17.019608
# Name: Years_of_Experience, dtype: float64

# %%
plot_data = dict(insured.groupby(insured['Education_Level']).Salary.mean())
plot_keys = list(plot_data.keys())
plot_values = list(plot_data.values())
print(plot_data)
print(plot_keys)
print(plot_values)
# Out:
# {"Bachelor's": 74756.02678571429, "Master's": 129795.91836734694, 'PhD': 157843.13725490196}
# ["Bachelor's", "Master's", 'PhD']
# [74756.02678571429, 129795.91836734694, 157843.13725490196]

# %%
insured.groupby(insured['Education_Level']).Salary.mean().plot.bar()
# Out:
# <Axes: xlabel='Education_Level'>

# %%
sns.barplot(x=insured.Gender,y = insured.Salary).set(title ="Gender vs Salary")
# Out:
# [Text(0.5, 1.0, 'Gender vs Salary')]

# %%
sns.barplot(x=insured.Education_Level,y=insured.Salary).set(title ="Education Level vs Salary")
# Out:
# [Text(0.5, 1.0, 'Education Level vs Salary')]

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x = insured["Gender"], y =insured["Salary"],hue=insured["Education_Level"],ci=1).set(title= 'Salary of males and females wrt Education')
plt.legend(bbox_to_anchor=(0.5, 1))
plt.show()

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x=insured['Gender'],y=insured['Age'],hue =insured['Education_Level'],ci=1).set(title = "Age of male and female wrt to Education level")
plt.legend(bbox_to_anchor=(0.5,1))
plt.show()

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x=insured['Gender'],y=insured['Years_of_Experience'],hue =insured['Education_Level'],ci=1).set(title = "Experience of male and female wrt to Education level")
plt.legend(bbox_to_anchor=(0.5,1))
plt.show()

# %%
gender_salary = pd.crosstab(index = insured['Education_Level'],columns=insured['Gender'],values=insured['Salary'],aggfunc='mean')
gender_salary
# Out:
# Gender                  Female           Male
# Education_Level
# Bachelor's        71019.417476   77936.776860
# Master's         120200.000000  139791.666667
# PhD              155384.615385  160400.000000

# %%
edu_gender_salary = pd.crosstab(index = insured.Education_Level,columns = insured.Gender,values=insured.Salary,aggfunc='mean')
edu_gender_salary
# Out:
# Gender                  Female           Male
# Education_Level
# Bachelor's        71019.417476   77936.776860
# Master's         120200.000000  139791.666667
# PhD              155384.615385  160400.000000

# %%
gender_edu_salary = pd.crosstab(index = insured.Gender,columns = insured.Education_Level,values=insured.Salary,aggfunc='sum')
gender_edu_salary
# Out:
# Education_Level  Bachelor's   Master's        PhD
# Gender
# Female            7315000.0  6010000.0  4040000.0
# Male              9430350.0  6710000.0  4010000.0

# %%
edu_gender_salary.plot(kind='bar',title='Education vs Gender vs Salary')
plt.legend(loc= 'upper left')
plt.show()

# %%
gender_edu_salary.plot(kind='bar',title='Education vs Gender vs Salary')
plt.legend(loc= 'upper left')
plt.show()

# %%
#converting quntitative data into qualitative data
insured
# Out:
#       Age  Gender Education_Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years_of_Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
insured.describe()
# Out:
#               Age  Years_of_Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
# Creating a group of age 
category = pd.cut(insured.Age,bins = [20,25,30,35,40,45,50,55,60],labels =['20-25','25-30','30-35','35-40','40-45','45-50','50-55','60-65'])
category
# Out:
# 0      30-35
# 1      25-30
# 2      40-45
# 3      35-40
# 4      50-55
#        ...
# 370    30-35
# 371    40-45
# 372    25-30
# 373    30-35
# 374    40-45
# Name: Age, Length: 373, dtype: category
# Categories (8, object): ['20-25' < '25-30' < '30-35' < '35-40' < '40-45' < '45-50' < '50-55' < '60-65']

# %%
insured.insert(1,'AgeGroup',category)
insured
# Out:
#       Age AgeGroup  Gender Education_Level                      Job Title  \
# 0    32.0    30-35    Male      Bachelor's              Software Engineer
# 1    28.0    25-30  Female        Master's                   Data Analyst
# 2    45.0    40-45    Male             PhD                 Senior Manager
# 3    36.0    35-40  Female      Bachelor's                Sales Associate
# 4    52.0    50-55    Male        Master's                       Director
# ..    ...      ...     ...             ...                            ...
# 370  35.0    30-35  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    40-45    Male        Master's         Director of Operations
# 372  29.0    25-30  Female      Bachelor's         Junior Project Manager
# 373  34.0    30-35    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0    40-45  Female             PhD        Senior Business Analyst
#
#      Years_of_Experience    Salary
# 0                    5.0   90000.0
# ...

# %%
age_group = insured.groupby(insured['AgeGroup']).Salary.mean()
age_group
# Out:
# AgeGroup
# 20-25     35833.333333
# 25-30     43288.805970
# 30-35     74375.000000
# 35-40     97222.222222
# 40-45    139315.068493
# 45-50    168700.000000
# 50-55    183888.888889
# 60-65              NaN
# Name: Salary, dtype: float64

# %%
category1 = pd.cut(insured['Years_of_Experience'],bins =[0,5,10,15,20],labels =['0-5','5-10','10-15','15-20'])
category1
# Out:
# 0        0-5
# 1        0-5
# 2      10-15
# 3       5-10
# 4      15-20
#        ...
# 370     5-10
# 371    15-20
# 372      0-5
# 373     5-10
# 374    10-15
# Name: Years_of_Experience, Length: 373, dtype: category
# Categories (4, object): ['0-5' < '5-10' < '10-15' < '15-20']

# %%
insured.insert(6,'Exp_level',category1)
insured
# Out:
#       Age AgeGroup  Gender Education_Level                      Job Title  \
# 0    32.0    30-35    Male      Bachelor's              Software Engineer
# 1    28.0    25-30  Female        Master's                   Data Analyst
# 2    45.0    40-45    Male             PhD                 Senior Manager
# 3    36.0    35-40  Female      Bachelor's                Sales Associate
# 4    52.0    50-55    Male        Master's                       Director
# ..    ...      ...     ...             ...                            ...
# 370  35.0    30-35  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    40-45    Male        Master's         Director of Operations
# 372  29.0    25-30  Female      Bachelor's         Junior Project Manager
# 373  34.0    30-35    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0    40-45  Female             PhD        Senior Business Analyst
#
#      Years_of_Experience Exp_level    Salary
# ...

# %%
exp_level =insured.groupby(insured['Exp_level']).Salary.mean()
exp_level
# Out:
# Exp_level
# 0-5       49367.372881
# 5-10      92578.947368
# 10-15    118230.769231
# 15-20    159140.625000
# Name: Salary, dtype: float64

# %%
insured.head()
# Out:
#     Age AgeGroup  Gender Education_Level          Job Title  \
# 0  32.0    30-35    Male      Bachelor's  Software Engineer
# 1  28.0    25-30  Female        Master's       Data Analyst
# 2  45.0    40-45    Male             PhD     Senior Manager
# 3  36.0    35-40  Female      Bachelor's    Sales Associate
# 4  52.0    50-55    Male        Master's           Director
#
#    Years_of_Experience Exp_level    Salary
# 0                  5.0       0-5   90000.0
# 1                  3.0       0-5   65000.0
# 2                 15.0     10-15  150000.0
# 3                  7.0      5-10   60000.0
# 4                 20.0     15-20  200000.0

# %%
age_group.plot(kind = 'bar',title ="Agebins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Agebins vs Avg Salary'}, xlabel='AgeGroup'>

# %%
exp_level.plot(kind ="bar" ,title="experience level vs average salay")
# Out:
# <Axes: title={'center': 'experience level vs average salay'}, xlabel='Exp_level'>

# %%
insured.groupby(['Gender','Education_Level','Exp_level']).Salary.mean()
# Out:
# Gender  Education_Level  Exp_level
# Female  Bachelor's       0-5           47040.816327
#                          5-10          88225.806452
#                          10-15         92941.176471
#                          15-20        120000.000000
#         Master's         0-5           58750.000000
#                          5-10          93000.000000
#                          10-15        115000.000000
#                          15-20        170000.000000
#         PhD              0-5                    NaN
#                          5-10                   NaN
#                          10-15        147727.272727
#                          15-20        153636.363636
# Male    Bachelor's       0-5           49158.474576
#                          5-10          90833.333333
#                          10-15        125384.615385
#                          15-20        121875.000000
#         Master's         0-5           75000.000000
# ...

# %%
insured.groupby(['Gender','Education_Level','Exp_level']).Salary.mean().unstack()
# Out:
# Exp_level                        0-5           5-10          10-15  \
# Gender Education_Level
# Female Bachelor's       47040.816327   88225.806452   92941.176471
#        Master's         58750.000000   93000.000000  115000.000000
#        PhD                       NaN            NaN  147727.272727
# Male   Bachelor's       49158.474576   90833.333333  125384.615385
#        Master's         75000.000000  102941.176471  126250.000000
#        PhD                       NaN  110000.000000  126250.000000
#
# Exp_level                       15-20
# Gender Education_Level
# Female Bachelor's       120000.000000
#        Master's         170000.000000
#        PhD              153636.363636
# Male   Bachelor's       121875.000000
#        Master's         172750.000000
#        PhD              164333.333333

# %%
insured.groupby(['Gender','Education_Level','Exp_level']).Salary.mean().unstack().plot(kind="bar",title ="Exp_bins vs average salary")
# Out:
# <Axes: title={'center': 'Exp_bins vs average salary'}, xlabel='Gender,Education_Level'>

# %%
insured.groupby(['Gender','Education_Level','Exp_level']).Salary.mean().plot(kind="bar",title ="Exp_bins vs average salary")
# Out:
# <Axes: title={'center': 'Exp_bins vs average salary'}, xlabel='Gender,Education_Level,Exp_level'>

# %%
insured.groupby(['Education_Level','Exp_level','Gender']).Salary.mean().unstack().plot(kind="bar",title ="Exp_bins vs average salary")
# Out:
# <Axes: title={'center': 'Exp_bins vs average salary'}, xlabel='Education_Level,Exp_level'>

# %%
plt.figure(figsize = (15,7))
sns.barplot(x =insured['Education_Level'],y = insured['Salary'],hue =insured['Gender'],ci=0).set(title ="Education vs Salary on the basis of Gender")
plt.legend(bbox_to_anchor=(1.00,1))
plt.show()

# %%
sns.relplot(x= insured['Salary'],y=insured['Years_of_Experience'],hue = insured['Gender'],size = insured['Education_Level'],sizes=(40,400),palette="spring",height=6,data=insured).set(title="Salary by Education ,Gender,Years of Experience ")

# %%
sns.relplot(x= insured['Salary'],y=insured['Years_of_Experience'],hue = insured['Education_Level'],size = insured['Gender'],sizes=(40,400),palette="spring",height=6,data=insured).set(title="Salary by Education ,Gender,Years of Experience ")
